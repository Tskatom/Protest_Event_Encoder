# %%
f1 = "/home/tskatom/workspace/Protest_Event_Encoder/data/autogsr_data_oct_dec_2015.json"
f2 = "/home/tskatom/workspace/Protest_Event_Encoder/data/autogsr_data_jan_2016.json"

import json

docs1 = [json.loads(l) for l in open(f1)]
docs2 = [json.loads(l) for l in open(f2)]
docs = docs1 + docs2

# %%
set([d['country'] for d in docs])
# Out:
# {u'Argentina',
#  u'Brazil',
#  u'Chile',
#  u'Colombia',
#  u'Ecuador',
#  u'El Salvador',
#  u'Mexico',
#  u'Paraguay',
#  u'Uruguay',
#  u'Venezuela'}

# %%
d
# Out:
# {u'aid': 51251,
#  u'country': u'Venezuela',
#  u'domain': u'el-nacional',
#  u'encodings': [{u'type': u'Non-Protest'}],
#  u'fetch_date': u'2016-01-31',
#  u'meta_basis': u'',
#  u'meta_tags': [],
#  u'source': u'www.el-nacional.com',
# ...
